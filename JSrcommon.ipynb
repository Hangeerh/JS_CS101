# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import altair as alt
import time

url = "https://data.cityofchicago.org/resource/85ca-t3if.csv?$limit=1000000"



##################################################
# Pandas Option 1: Read the dataset from local file
#     It took my program 10 minutes to load it across the web.
#     So load locally.
##################################################
start = time.time()
df = pd.read_csv(r"/Users/annawierzchon/CRASH.csv")
end = time.time()

print(f"Stored dataset locally! It took {end-start} seconds to load into dataframe.")
print(df.head)
print(df.shape)
print(df.columns.tolist())
# Out:
# Stored dataset locally! It took 4.216177701950073 seconds to load into dataframe.
# <bound method NDFrame.head of                                            CRASH_RECORD_ID CRASH_DATE_EST_I  \
# 0        000c4307d8e9b39075cffdd0aade3603e0f96f14e41da9...              NaN
# 1        027b0b4c21460d3441fd83929abb9673c6fc0c7d575675...              NaN
# 2        04d91dffc94f677358ca47056921ba5c4224320df27ed4...                Y
# 3        0b5603954d84b7341c7cad4f570ea039e85919f3750ccb...              NaN
# 4        00bce77960c2faa2a8782a8cac1d6e5715802d6c072a08...              NaN
# ...                                                    ...              ...
# 1037159  5ff5b050ae2079df6addca8431c1bd6e381432ff72ff43...              NaN
# 1037160  7a7963ac15a38f3cf7549397dd053fd7612dd5194de280...              NaN
# 1037161  84e546c12fd8fd78ae4e2dc26fdb02d6e8f6c4c92be450...              NaN
# 1037162  8237045757e7fed5adfb450bd7c8472e28a61d322f86bb...              NaN
# ...

# %%
##################################################
# Data cleaning that helps all of the team
##################################################

# %%
##################################################
# Anna's Seaborn Plot
##################################################

# %%
##################################################
# Anna's Plotly Express Plot
##################################################

# %%
##################################################
# Anna's Altair Plot
##################################################

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\terwi'

# %%
import seaborn as sns
import plotly.express as plt
import altair as alt

# %%
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
